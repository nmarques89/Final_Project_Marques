# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
#import tensorflow as tf

# %%
project_df = pd.read_csv("resources/salary.csv")
project_df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
project_df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
project_df.sample(20)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 30120   44            Private  191149   Some-college             10
# 4884    26                  ?  176077   Some-college             10
# 31878   61       Self-emp-inc  148577        HS-grad              9
# 12617   47       Self-emp-inc  127678   Some-college             10
# 27120   37            Private  112497    Prof-school             15
# 18650   23          Local-gov  336010      Bachelors             13
# 28358   62          Local-gov  206063   Some-college             10
# 30110   46            Private  213140      Bachelors             13
# 10036   39       Self-emp-inc  126675   Some-college             10
# 3789    33            Private  171216      Bachelors             13
# 30163   36                  ?  187203      Assoc-voc             11
# 28144   21                  ?  191806   Some-college             10
# 3440    23       Self-emp-inc  214542   Some-college             10
# 18985   45          Local-gov   93535        Masters             14
# 17827   25            Private  114838    Prof-school             15
# 18082   28   Self-emp-not-inc  190391      Bachelors             13
# 5648    45          State-gov   67544        Masters             14
# 20812   20            Private  103840        HS-grad              9
# 19428   41            Private  145220            9th              5
# 4661    45            Private  162187      Bachelors             13
#
#             marital-status          occupation    relationship    race  \
# 30120             Divorced        Adm-clerical       Unmarried   White
# 4884         Never-married                   ?       Unmarried   White
# 31878   Married-civ-spouse               Sales         Husband   White
# 12617   Married-civ-spouse               Sales         Husband   White
# 27120   Married-civ-spouse      Prof-specialty         Husband   White
# 18650        Never-married        Adm-clerical   Not-in-family   White
# 28358             Divorced       Other-service   Not-in-family   White
# 30110   Married-civ-spouse      Prof-specialty         Husband   White
# 10036   Married-civ-spouse      Prof-specialty         Husband   White
# 3789    Married-civ-spouse     Exec-managerial         Husband   White
# 30163             Divorced                   ?       Own-child   White
# 28144        Never-married                   ?       Own-child   White
# 3440         Never-married      Prof-specialty   Not-in-family   White
# 18985             Divorced      Prof-specialty       Unmarried   White
# 17827        Never-married      Prof-specialty   Not-in-family   White
# 18082        Never-married               Sales   Not-in-family   White
# 5648              Divorced     Protective-serv   Not-in-family   White
# 20812        Never-married   Machine-op-inspct       Own-child   White
# 19428        Never-married     Priv-house-serv       Unmarried   White
# 4661    Married-civ-spouse               Sales         Husband   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 30120   Female             0             0              57   United-States
# 4884    Female             0             0              40   United-States
# 31878     Male             0             0              55   United-States
# 12617     Male             0             0              80   United-States
# 27120     Male             0             0              50   United-States
# 18650     Male             0             0              32   United-States
# 28358     Male             0             0              45   United-States
# 30110     Male             0             0              40               ?
# 10036     Male             0             0              25   United-States
# 3789      Male             0             0              50   United-States
# 30163     Male             0             0              50   United-States
# 28144     Male             0             0              75   United-States
# 3440      Male             0             0              50   United-States
# 18985   Female             0             0              40   United-States
# 17827   Female             0             0               8           Italy
# 18082     Male             0             0              50   United-States
# 5648      Male             0             0              50   United-States
# 20812   Female             0             0              42   United-States
# 19428   Female             0             0              40        Columbia
# 4661      Male             0             0              52   United-States
#
#        salary
# 30120   <=50K
# 4884    <=50K
# 31878    >50K
# 12617   <=50K
# 27120    >50K
# 18650   <=50K
# 28358   <=50K
# 30110    >50K
# 10036   <=50K
# 3789     >50K
# 30163   <=50K
# 28144   <=50K
# 3440    <=50K
# 18985   <=50K
# 17827   <=50K
# 18082   <=50K
# 5648    <=50K
# 20812   <=50K
# 19428   <=50K
# 4661     >50K

# %%
project_df.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        119
# capital-loss         92
# hours-per-week       94
# native-country       42
# salary                2
# dtype: int64

# %%
## Create Features DataFrame
features_df = project_df.filter(['age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex','hours-per-week', 'native-country' ], axis = 1)
features_df
# Out:
#        age          workclass    education       marital-status  \
# 0       39          State-gov    Bachelors        Never-married
# 1       50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2       38            Private      HS-grad             Divorced
# 3       53            Private         11th   Married-civ-spouse
# 4       28            Private    Bachelors   Married-civ-spouse
# ...    ...                ...          ...                  ...
# 32556   27            Private   Assoc-acdm   Married-civ-spouse
# 32557   40            Private      HS-grad   Married-civ-spouse
# 32558   58            Private      HS-grad              Widowed
# 32559   22            Private      HS-grad        Never-married
# 32560   52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex  hours-per-week  \
# 0            Adm-clerical   Not-in-family   White     Male              40
# 1         Exec-managerial         Husband   White     Male              13
# 2       Handlers-cleaners   Not-in-family   White     Male              40
# 3       Handlers-cleaners         Husband   Black     Male              40
# 4          Prof-specialty            Wife   Black   Female              40
# ...                   ...             ...     ...      ...             ...
# 32556        Tech-support            Wife   White   Female              38
# 32557   Machine-op-inspct         Husband   White     Male              40
# 32558        Adm-clerical       Unmarried   White   Female              40
# 32559        Adm-clerical       Own-child   White     Male              20
# 32560     Exec-managerial            Wife   White   Female              40
#
#        native-country
# 0       United-States
# 1       United-States
# 2       United-States
# 3       United-States
# 4                Cuba
# ...               ...
# 32556   United-States
# 32557   United-States
# 32558   United-States
# 32559   United-States
# 32560   United-States
#
# [32561 rows x 10 columns]

# %%
#create target df
target_df = project_df.filter(['age','salary'], axis=1)
target_df
# Out:
#        age  salary
# 0       39   <=50K
# 1       50   <=50K
# 2       38   <=50K
# 3       53   <=50K
# 4       28   <=50K
# ...    ...     ...
# 32556   27   <=50K
# 32557   40    >50K
# 32558   58   <=50K
# 32559   22   <=50K
# 32560   52    >50K
#
# [32561 rows x 2 columns]

# %%
# Renaming titles columns
features_df = features_df.rename(columns={'workclass':'work_class','marital-status': 'martial_status','hours-per-week':'hours_per_week','native-country':'native_country'})
features_df
# Out:
#        age         work_class    education       martial_status  \
# 0       39          State-gov    Bachelors        Never-married
# 1       50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2       38            Private      HS-grad             Divorced
# 3       53            Private         11th   Married-civ-spouse
# 4       28            Private    Bachelors   Married-civ-spouse
# ...    ...                ...          ...                  ...
# 32556   27            Private   Assoc-acdm   Married-civ-spouse
# 32557   40            Private      HS-grad   Married-civ-spouse
# 32558   58            Private      HS-grad              Widowed
# 32559   22            Private      HS-grad        Never-married
# 32560   52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex  hours_per_week  \
# 0            Adm-clerical   Not-in-family   White     Male              40
# 1         Exec-managerial         Husband   White     Male              13
# 2       Handlers-cleaners   Not-in-family   White     Male              40
# 3       Handlers-cleaners         Husband   Black     Male              40
# 4          Prof-specialty            Wife   Black   Female              40
# ...                   ...             ...     ...      ...             ...
# 32556        Tech-support            Wife   White   Female              38
# 32557   Machine-op-inspct         Husband   White     Male              40
# 32558        Adm-clerical       Unmarried   White   Female              40
# 32559        Adm-clerical       Own-child   White     Male              20
# 32560     Exec-managerial            Wife   White   Female              40
#
#        native_country
# 0       United-States
# 1       United-States
# 2       United-States
# 3       United-States
# 4                Cuba
# ...               ...
# 32556   United-States
# 32557   United-States
# 32558   United-States
# 32559   United-States
# 32560   United-States
#
# [32561 rows x 10 columns]

# %%
# Add this import for sql database
import sqlite3

# %%
# connecting to 'features.db'
conn = sqlite3.connect('Salary.db')

# %%
# Adding feature_df database
features_df.to_sql(name ='features', con=conn, if_exists='replace', index=False)
conn.commit
# Out:
# <function Connection.commit>

# %%
# Adding target_df to database
target_df.to_sql(name ='target', con=conn, if_exists='replace', index=False)
conn.commit
# Out:
# <function Connection.commit>

# %%
# connecting to 'target.db'
conn = sqlite3.connect('salary.db')

# %% [markdown]
# # Test and Train
